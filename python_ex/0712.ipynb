# %%
print("헬로") #shift+ Enter
# Out:
# 헬로

# %%
a=4 #대입 연산자 #ctrl + Enter

# %%
a
# Out:
# 4

# %%
a=8

# %%
a
# Out:
# 8

# %%
b=6
b
# Out:
# 6

# %%
a+b
# Out:
# 14

# %%
c= a+b #assign(대입하면 됨,패턴 > 구조화)

# %%
c
# Out:
# 14

# %%
a = "윤세빈" #a는 동적타입(실행할 때마다 바꿀 수 있음) <-> 정적타입
a
# Out:
# '윤세빈'

# %%
type(a)
# Out:
# str

# %%
type(b)
# Out:
# int

# %%
type(c)
# Out:
# int

# %%
f= 1.414
f
print(f) #Ctrl + 화살표 , Shift + 화살표
type(f) #파이썬은 마지막 코드만 출력됨(f만 적을 경우 출력되지 않음 > print(f))
print(type(f)) #Alt + 화살표 (문장 위치를 바꿀 수 있음)
# Out:
# 1.414
# <class 'float'>
