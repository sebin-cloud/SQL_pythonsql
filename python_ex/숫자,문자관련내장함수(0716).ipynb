# %%
a=2
b=4

# %%
print(f"입력한 값.{a}")
# Out:
# 입력한 값.2

# %%
print("입력한 값 {}".format(a))
# Out:
# 입력한 값 2

# %%
print("입력한 값 {},{},{}".format(a,b,a+b))
# Out:
# 입력한 값 2,4,6

# %%
print(f"입력한 값 {a},{b},{a+b}")
# Out:
# 입력한 값 2,4,6

# %%
a = f"입력한 값 {a},{b},{a+b}"
a
# 메모리 > 변수에 입력, 터미널(print)
# Out:
# '입력한 값 2,4,6'

# %%
#ctrl +z + shift
#문자열에 중괄호 3개표시에 format의 변수가 2개 > index오류 (개수가 맞지 않은 것)
c=1
print("입력한 값 {},{},{}".format(a,b,c))
# Out:
# 입력한 값 입력한 값 2,4,6,4,1

# %% [markdown]
# #정수값 포매팅

# %%
#digit : 숫자값 (뒤에서 부터 쌓아나간다)
"{:5d}".format(52)
# Out:
# '   52'

# %%
print("{:5d}".format(+52))
print("{:5d}".format(-52))
print("{:5d}".format(52))
print("{:+5d}".format(+52))
print("{:+5d}".format(-52))
print("{:+5d}".format(52))
# Out:
#    52
#   -52
#    52
#   +52
#   -52
#   +52

# %%
# float : 소수점
# 반올림 됨 (소수점 아래가 0이면 {:g}로 없애기 > 메모리만 차지함)

# %%
format_a = "{}만원".format(1000)
format_a
# Out:
# '1000만원'

# %%
format_b = "파이썬 열공하여 {}만원 벌어보기".format(5000)
format_b
# Out:
# '파이썬 열공하여 5000만원 벌어보기'

# %%
format_c = "{},{},{}".format(1000,2000,3000)
format_c
# Out:
# '1000,2000,3000'

# %%
format_d = "{},{},{}".format(1,"문자열",True)
format_d
# Out:
# '1,문자열,True'

# %%
output_d = "{:05d}".format(52)
print(output_d)
# Out:
# 00052

# %% [markdown]
# #공백문자 제거

# %%
data = input("데이터 입력 >> ")
#공백 제거가 원칙
# Out:
# 데이터 입력 >>    윤세빈

# %%
data = data.strip()
data
# 함수와 method의 차이 : print() , .format()
# class 안에 정의되어있는 것은 반드시 매서드로 만들어야됨 .strip()
# Out:
# '윤세빈'

# %% [markdown]
# print는 터미널에만 찍는 것 print(a+b)
# 변수 지정을 해야 메모리에 올라가는 것 a = a+b

# %%
"윤세빈1024".isdecimal()
#is로 시작하는 함수 : 이냐?
# Out:
# False

# %%
True , False
# true, false #ctrl + / 하면 주석으로 바뀜
type(False)
# 조건문에서는 bool type으로 나와야함
# 함수로 쓰고 있는 경우에는 해당 이름을 변수 이름으로 활용하면 안됨 > 예약어
# Out:
# bool

# %%
"~nums".isidentifier()
# Out:
# False

# %% [markdown]
# #파이썬의 네이밍 컨벤션
# ## 변수
# - 영어
# - 영어+숫자
# - 워드_워드
#
# ##함수
# - 첫워드소문자_첫글자대문자나머지소문자
#   - dataPreprecess
#
#
# ##클래스
# - 영어

# %% [markdown]
# # 문자열 특정기호로 분할

# %%
nums = input("숫자 두개 입력>>")
# Out:
# 숫자 두개 입력>>6 7

# %%
nums
# Out:
# '6 7'

# %%
nums[0]
nums[1]
nums[2]
# Out:
# '7'

# %%
nums1 = input("숫자 두개 입력 >>")
# Out:
# 숫자 두개 입력 >>5,7

# %%
nums.split()
# Out:
# ['6', '7']

# %%
# ","는 split()의 전달인자(arguments)
result = nums1.split(",")
print(int(result[0]))
print(int(result[1]))
print(result)
# Out:
# 5
# 7
# ['5', '7']

# %% [markdown]
# ##문제2

# %%
num = input("숫자 두개를 입력해주세요 >> ")
num = num.split(",")
num1 = eval(num[0])
num2 = eval(num[1])
# Out:
# 숫자 두개를 입력해주세요 >> 4,20

# %%
print("두수의 연산결과")
print("-"*20)
print(f"{num1} + {num2} = {num1+num2}")
print(f"{num1} - {num2} = {num1-num2}")
print(f"{num1} * {num2} = {num1*num2}")
print(f"{num1} / {num2} = {num1/num2}")
print(f"{num1} % {num2} = {num1%num2}")
print(f"{num1} // {num2} = {num1//num2}")
# Out:
# 두수의 연산결과
# --------------------
# 4 + 20 = 24
# 4 - 20 = -16
# 4 * 20 = 80
# 4 / 20 = 0.2
# 4 % 20 = 4
# 4 // 20 = 0

# %% [markdown]
# ##문제3

# %%
num3 = input("입력하세요")
if  num3.isalpha == True :
      print("문자만 있습니다")
if  num3.isdigit == True :
      print("숫자만 있습니다")
if  num3.isalnum == True :
      print("숫자와 문자가 있습니다")
# Out:
# 입력하세요hello

# %%
#메모리에 아래와 같이 올려놓아야함
money = True
money
# Out:
# True

# %%
# :는 문장의 끝이 아님 서브로 들어갈 수 있음
#if,else > 실행하고 빠져나감,한문장임  /  if,ifnot > 두문장
if money:
  print("택시타기")
if not(money):
  print("걷기")
# Out:
# 택시타기

# %%
money = 2000

if money > 4000:
  print("지하철")
elif money >= 2000 :
  print("택시타기")
else :
  print("걷기")
# Out:
# 택시타기

# %%
#data = "aaaa123"
#data = "aaaa"
#data = "123"
data = "aaa-123"

if data.isnumeric() :
  print("숫자만 있음")
elif data.isalpha() :
  print("문자만 있음")
elif data.isalnum() :
  print("숫자,문자있음")
else :
  print("나머지")
# Out:
# 나머지
