# %% [markdown]
# #파이썬 기본문법

# %% [markdown]
# ## 자료형

# %%
print("이름 나이 지역")
# Out:
# 이름 나이 지역

# %%
print("이름\t 나이\t 지역")
# Out:
# 이름	 나이	 지역

# %%
print('\\') #역슬래시를 탈출시키는
# Out:
# \

# %%
print("동해물과 백두산이 마르고 달토록 \n하느님이 보우하사 우리나라 만세")
# Out:
# 동해물과 백두산이 마르고 달토록
# 하느님이 보우하사 우리나라 만세

# %%
print("""동해물과 백두산이 마르고 달토록
하느님이 보우하사 우리나라 만세""") # """"은 내가 입력한 그대로 출력되는 것
# Out:
# 동해물과 백두산이 마르고 달토록
# 하느님이 보우하사 우리나라 만세

# %%
input()
# Out:
# 애국가
# '애국가'

# %%
'사과' + '바나나' #문자열 + 문자열끼리는 연산이 가능 #오류가 났을 때 눈여겨 보는 것이 중요
# Out:
# '사과바나나'

# %%
#str = "윤세빈" #이렇게 함수를 변수로 쓰면 안됨(동적이기 때문) #이렇게 할 경우에는 리셋을 해야함(런타임 > 세션다시시작 )

# %%
num=2

# %%
print(str(num))
type(num) #num을 str로 바꿨는데 왜 int로 나올까? num을 어딘가에 대입을 안했기 때문

num = str(num)
type(num)
# Out:
# 2
# str

# %% [markdown]
# - 숫자 -> 문자로 변환 : 형변환, casting이라고 부름

# %% [markdown]
# # 문자열 인덱싱 (문자하나에 자료 하나)

# %%
data_str = "윤세빈"  #assign(대입)한다 = 메모리 사용하고 있다

# %%
data_str
# Out:
# '윤세빈'

# %%
#인덱싱(하나만) = 슬라이싱(범위)(예외적인 상황말고 항상 0부터 시작)
# 인덱스 범위를 벗어나서 인덱싱을 하면 오류남
# 0 ~ 3-1까지 범위를 참조함
data_str[0:3]
# Out:
# '윤세빈'

# %%
data_str[0:]
# Out:
# '윤세빈'

# %% [markdown]
# # 사용자로부터 자료입력받기

# %%
x = input()
x
# Out:
# 홍길동
# '홍길동'

# %%
nums = input("숫자를 넣으세요>>")
# Out:
# 숫자를 넣으세요>>10

# %%
print(nums) #shift+alt+화살표아래(아래로 문장이 복사됨)
print(type(nums))
# Out:
# 10
# <class 'str'>

# %%
nums = int(nums) #형변환 = casting #입력받으면 무조건 문자열로 들어옴
type(nums)
# Out:
# int

# %%
float(nums)
# Out:
# 10.0

# %%
num1 = input("숫자를 넣으세요>>")
# Out:
# 숫자를 넣으세요>>12.5

# %%
num1 = eval(num1) #eval = 실수,정수 둘다로 정의
type(num1)
# Out:
# float

# %% [markdown]
# ##문제1

# %%
a = input("숫자를 입력해주세요 >>")
b = input("숫자를 입력해주세요 >>")
a= eval(a)
b= eval(b)
# Out:
# 숫자를 입력해주세요 >>4
# 숫자를 입력해주세요 >>10

# %%
print("두수의 연산 결과")
print("-"*20)
print(f"{a} + {b} = {a+b}")
print(f"{a} - {b} = {a-b}")
print(f"{a} * {b} = {a*b}")
print(f"{a} % {b} = {a%b}")
print(f"{a} // {b} = {a//b}")
# Out:
# 두수의 연산 결과
# --------------------
# 4 + 10 = 14
# 4 - 10 = -6
# 4 * 10 = 40
# 4 % 10 = 4
# 4 // 10 = 0
